# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")
sns.set()

from sklearn.linear_model import LogisticRegression

from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %%
data = pd.read_csv("C:/Users/Eric.Niyitanga/Downloads/Predicting Heart disease/train.csv")
data.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# ...

# %%
data.isna().sum()
# Out:
# id                         0
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Age, Sex, Chest pain type, BP, Cholesterol, FBS over 120, EKG results, Max HR, Exercise angina, ST depression, Slope of ST, Number of vessels fluro, Thallium, Heart Disease]
# Index: []

# %%
df= data.copy()

# %%
df['Heart Disease']= df['Heart Disease'].map({'Presence':1, 'Absence':0})
df.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        2         7              1
# 1                        0         3              0
# ...

# %%
df.describe()
# Out:
#                   id            Age            Sex  Chest pain type  \
# count  630000.000000  630000.000000  630000.000000    630000.000000
# mean   314999.500000      54.136706       0.714735         3.312752
# std    181865.479132       8.256301       0.451541         0.851615
# min         0.000000      29.000000       0.000000         1.000000
# 25%    157499.750000      48.000000       0.000000         3.000000
# 50%    314999.500000      54.000000       1.000000         4.000000
# 75%    472499.250000      60.000000       1.000000         4.000000
# max    629999.000000      77.000000       1.000000         4.000000
#
#                   BP    Cholesterol   FBS over 120    EKG results  \
# count  630000.000000  630000.000000  630000.000000  630000.000000
# mean      130.497433     245.011814       0.079987       0.981660
# std        14.975802      33.681581       0.271274       0.998783
# min        94.000000     126.000000       0.000000       0.000000
# ...

# %%
# df = df.drop('id', axis=1)

# %%
df.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        2         7              1
# 1                        0         3              0
# ...

# %%
y = df['Heart Disease']
x = df.drop('Heart Disease', axis=1)

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
model.predict(x)
# Out:
# array([1, 0, 0, ..., 1, 0, 0], shape=(630000,))

# %%
x1 = sm.add_constant(x)
models = sm.Logit(y,x1).fit()
models.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.281742
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          Heart Disease   No. Observations:               630000
# Model:                          Logit   Df Residuals:                   629985
# Method:                           MLE   Df Model:                           14
# Date:                Sun, 15 Mar 2026   Pseudo R-squ.:                  0.5904
# Time:                        12:17:54   Log-Likelihood:            -1.7750e+05
# converged:                       True   LL-Null:                   -4.3331e+05
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
def confusion_matrix(data, actual_values, model):
    pred_values= model.predict(data)
    bins = np.array([0,0.5,1])
    cm = np.histogram2d(actual_values, pred_values, bins= bins)[0]
    accuracy = (cm[0,0] + cm[1,1])/cm.sum()
    return cm, accuracy

# %%
confusion_matrix(x1, y, models)
# Out:
# (array([[314476.,  33070.],
#         [ 40559., 241895.]]),
#  np.float64(0.8831285714285714))

# %%
d_test = pd.read_csv('C:\\Users\\Eric.Niyitanga\\Downloads\\Predicting Heart disease\\test.csv')
# d_test1 = d_test.drop('id', axis=1)
d_test.head()
# Out:
#        id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0  630000   58    1                3  120          288             0
# 1  630001   55    0                2  120          209             0
# 2  630002   54    1                4  120          268             0
# 3  630003   44    0                3  112          177             0
# 4  630004   43    1                1  138          267             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     145                1            0.8            2
# 1            0     172                0            0.0            1
# 2            0     150                1            0.0            2
# 3            0     168                0            0.9            1
# 4            0     163                0            1.8            2
#
#    Number of vessels fluro  Thallium
# 0                        3         3
# 1                        0         3
# ...

# %%
d_test.describe()
# Out:
#                   id            Age            Sex  Chest pain type  \
# count  270000.000000  270000.000000  270000.000000    270000.000000
# mean   764999.500000      54.159870       0.716315         3.315107
# std     77942.430678       8.255471       0.450787         0.851762
# min    630000.000000      29.000000       0.000000         1.000000
# 25%    697499.750000      48.000000       0.000000         3.000000
# 50%    764999.500000      54.000000       1.000000         4.000000
# 75%    832499.250000      60.000000       1.000000         4.000000
# max    899999.000000      77.000000       1.000000         4.000000
#
#                   BP    Cholesterol   FBS over 120    EKG results  \
# count  270000.000000  270000.000000  270000.000000  270000.000000
# mean      130.555089     245.045270       0.080052       0.978493
# std        15.007908      33.695458       0.271374       0.998686
# min        94.000000     126.000000       0.000000       0.000000
# ...

# %%
model.predict(d_test)
# Out:
# array([1, 0, 1, ..., 0, 0, 0], shape=(270000,))

# %%
d_test['predict'] = model.predict(d_test)

# %%
# pd.set_option('display.max_rows', None) # this codes runs all obervations
# pd.set_option('display.max_columns', None) # This code runs all observations

d_test.head()
# Out:
#        id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0  630000   58    1                3  120          288             0
# 1  630001   55    0                2  120          209             0
# 2  630002   54    1                4  120          268             0
# 3  630003   44    0                3  112          177             0
# 4  630004   43    1                1  138          267             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     145                1            0.8            2
# 1            0     172                0            0.0            1
# 2            0     150                1            0.0            2
# 3            0     168                0            0.9            1
# 4            0     163                0            1.8            2
#
#    Number of vessels fluro  Thallium  predict
# 0                        3         3        1
# 1                        0         3        0
# ...

# %%
results= d_test[['id','predict']]

# %%
results.to_csv('C:/Users/Eric.Niyitanga/Downloads/Predicting Heart disease/Results.csv, index=False')

# %%
d_test.groupby('Sex')['predict'].mean().sort_values(ascending=False)
# Out:
# Sex
# 1    0.460159
# 0    0.263725
# Name: predict, dtype: float64
