# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
# nltk.download_shell()

# %% [markdown]
# messages = [line.rstrip() for line in open('C:/Users/Eric.Niyitanga/Downloads/sms+spam+collection/SMSSpamCollection')]

# %%
messages = [line.rstrip() for line in open('SMSSpamCollection')]

# %%
import pandas as pd
