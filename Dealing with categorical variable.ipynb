# %% [markdown]
# ### 1. df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})

# %% [markdown]
# ### 2. df.replace({'Male': 1, 'Female': 0}, inplace=True)

# %% [markdown]
# ### 3. from sklearn.preprocessing import LabelEncoder
#
# le = LabelEncoder()
#
# df['city'] = le.fit_transform(df['city'])

# %% [markdown]
# ### 4. df = pd.get_dummies(df, columns=['color'], drop_first=True)

# %% [markdown]
# ### 5. from sklearn.preprocessing import OneHotEncoder
#
# enc = OneHotEncoder(drop='first', sparse_output=False)
#
# encoded = enc.fit_transform(df[['color']])

# %% [markdown]
# ### 6. import category_encoders as ce
#
# encoder = ce.TargetEncoder(cols=['city'])
#
# df = encoder.fit_transform(df, df['target'])
