# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/Eric.Niyitanga/Downloads/Job Salary Prediction Dataset/job_salary_prediction_dataset.csv')
data.head()
# Out:
#             job_title  experience_years education_level  skills_count  \
# 0         AI Engineer                10        Bachelor             2
# 1        Data Analyst                 5        Bachelor            17
# 2  Frontend Developer                18             PhD             4
# 3    Business Analyst                19             PhD            13
# 4     Product Manager                15        Bachelor             7
#
#         industry company_size   location remote_work  certifications  salary
# 0     Healthcare       Medium      India      Hybrid               2  109413
# 1        Telecom        Small  Australia          No               0   93764
# 2          Media       Medium  Singapore          No               1  148123
# 3         Retail       Medium     Canada         Yes               0  189123
# 4  Manufacturing        Large     Sweden         Yes               0  165069

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['job_title'] = le.fit_transform(data['job_title'])
data['company_size'] = le.fit_transform(data['company_size'])
data['industry'] = le.fit_transform(data['industry'])
data['education_level'] = le.fit_transform(data['education_level'])
data['location'] = le.fit_transform(data['location'])
data['remote_work'] = le.fit_transform(data['remote_work'])

# %%
data.head()
# Out:
#    job_title  experience_years  education_level  skills_count  industry  \
# 0          0                10                0             2         4
# 1          5                 5                0            17         9
# 2          8                18                4             4         6
# 3          2                19                4            13         7
# 4         10                15                0             7         5
#
#    company_size  location  remote_work  certifications  salary
# 0             2         3            0               2  109413
# 1             3         0            1               0   93764
# 2             2         6            1               1  148123
# 3             2         1            2               0  189123
# 4             1         7            2               0  165069

# %%
le.classes_
# Out:
# array(['Hybrid', 'No', 'Yes'], dtype=object)

# %%
data.isnull().sum()
# Out:
# job_title           0
# experience_years    0
# education_level     0
# skills_count        0
# industry            0
# company_size        0
# location            0
# remote_work         0
# certifications      0
# salary              0
# dtype: int64

# %%
data.describe()
# Out:
#            job_title  experience_years  education_level   skills_count  \
# count  250000.000000     250000.000000    250000.000000  250000.000000
# mean        5.495124         10.005408         2.001560       9.997812
# std         3.456094          6.060602         1.413304       5.479288
# min         0.000000          0.000000         0.000000       1.000000
# 25%         2.000000          5.000000         1.000000       5.000000
# 50%         5.000000         10.000000         2.000000      10.000000
# 75%         9.000000         15.000000         3.000000      15.000000
# max        11.000000         20.000000         4.000000      19.000000
#
#             industry   company_size       location    remote_work  \
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean        4.488544       1.997796       4.495400       0.997708
# std         2.873043       1.411986       2.875013       0.815790
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.scatterplot(x= data['experience_years'], y= data['salary'])
# Out:
# <Axes: xlabel='experience_years', ylabel='salary'>

# %%
X= data.drop('salary', axis=1)
y= data['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)
